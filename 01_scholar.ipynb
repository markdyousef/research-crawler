# %%
# default_exp scholar

# %% [markdown]
# # scholar
#
# > API details.

# %%
import scholarly
import pandas as pd
from collections import Counter

# %%
authors = scholarly.search_keyword('EEG')

# %%
# _authors = [next(authors).fill() for _ in range(10)]
_authors = [next(authors) for _ in range(10)]

# %%
affiliations = []
for a in authors:
    affiliations.append(a.affiliation)

# %%
Counter(affiliations).most_common()
# Out:
# [('', 19),
#  ('Postdoctoral Researcher', 5),
#  ('University of California, Irvine', 4),
#  ('Institute of Higher Nervous Activity and Neurophysiology of RAS', 4),
#  ('University of Toronto', 3),
#  ('University of Zurich', 3),
#  ('US Army Research Laboratory', 3),
#  ('Researcher', 3),
#  ('Texas A&M University', 3),
#  ('Griffith University', 3),
#  ('Northwestern University', 3),
#  ("King's College London", 3),
#  ('Jagiellonian University', 3),
#  ('KU Leuven', 3),
#  ('Istituto Italiano di Tecnologia', 3),
#  ('University of Rochester', 3),
#  ('University of Colorado at Boulder', 2),
#  ('Radboud University', 2),
#  ('University of Genoa', 2),
#  ('University of Barcelona', 2),
#  ('University of Minnesota', 2),
#  ('McGill University', 2),
#  ('Penn State University', 2),
#  ('University of Montreal', 2),
#  ('Technische Universität Berlin', 2),
#  ('University of Calgary', 2),
#  ('University of Kent', 2),
#  ('University of California, Los Angeles', 2),
# ...

# %%
len(affiliations)
# Out:
# 1263
